# %% [markdown]
# #Additional Features for Dimension Table
# In this file Budget, Cast, Sequel Info, Collection, MPAA Rating, and Poster information are fetched using TMDb API.

# %% [markdown]
# #Importing Libraries

# %%
import pandas as pd
import numpy as np
import requests
import time
import os
import sys
import subprocess

# %% [markdown]
# #Loading Dataset

# %%
# 1. AUTO-INSTALL GDOWN (If missing)
try:
    import gdown
except ImportError:
    print("gdown not found. Installing...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "gdown"])
    import gdown

# 2. FILE MAPPING
# Map to the "Google Drive Link
file = {
    "dimension_table_v1.csv": "https://drive.google.com/file/d/1WyICY140G7DEtJ9oCjStAdFyKnIxsXr-/view?usp=share_link"}

# 3. DOWNLOADER LOOP
for filename, drive_link in file.items():
    if not os.path.exists(filename):
        print(f"Downloading {filename}...")

        # Extract ID from the link safely
        try:
            file_id = drive_link.split('/d/')[1].split('/')[0]
            url = f'https://drive.google.com/uc?id={file_id}'

            # Download (quiet=False shows the progress bar)
            gdown.download(url, filename, quiet=False)
        except IndexError:
            print(f"Error: Could not parse ID for {filename}. Check the link.")
    else:
        print(f"Found {filename} locally. Skipping download.")

# 4. LOAD DATA
print("\nLoading Dataframe...")

# Load Mojo (CSV)
if os.path.exists("dimension_table_v1.csv"):
    df = pd.read_csv("dimension_table_v1.csv")
    print("Dimension table V1 loaded.")
# Out:
# Downloading dimension_table_v1.csv...
# Downloading...
# From: https://drive.google.com/uc?id=1WyICY140G7DEtJ9oCjStAdFyKnIxsXr-
# To: /content/dimension_table_v1.csv
# 100%|██████████| 544k/544k [00:00<00:00, 8.02MB/s]
# Loading Dataframe...
# Dimension table V1 loaded.

# %%
df.head()
# Out:
#       tconst             Release  Opening_Week_Revenue Release_Date Theaters  \
# 0  tt1034303            Defiance                195622   2009-01-01        2
# 1  tt0959337  Revolutionary Road                 76319   2009-01-01        3
# 2  tt0841925        Silent Light                 19633   2009-01-07        1
# 3  tt0795438   Not Easily Broken               6143981   2009-01-09      724
# 4  tt0901476          Bride Wars              25827125   2009-01-09    3,226
#
#    Release_Year            Distributor                genres runtimeMinutes  \
# 0          2009      Paramount Vantage  Action,Drama,History            137
# 1          2009      Paramount Vantage         Drama,Romance            119
# 2          2009       Palisades Tartan         Drama,Romance            136
# 3          2009            Screen Gems         Drama,Romance             99
# 4          2009  Twentieth Century Fox        Comedy,Romance             89
#
#    directors     Special_Day
# 0  nm0001880  New Year's Day
# 1  nm0005222  New Year's Day
# 2  nm1196161             NaN
# 3  nm0004886             NaN
# 4  nm0935095             NaN

# %%
# CONFIGURATION

TMDB_READ_ACCESS_TOKEN = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMDYyZTkwY2E4MzM4OGNiNzMzYTc0Njg4MmZhZWE5NSIsIm5iZiI6MTc2MzEwMzIyMC4wNDQ5OTk4LCJzdWIiOiI2OTE2ZDFmNGU0ZjNmNTA1YWY0MGU2ZTIiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.91STVcbtmpYytLCt7AbqznoI2tYv394ee5fD-Dh8Lxw'
CHECKPOINT_FILE = 'dimension_table_checkpoint.csv'

TMDB_API_BASE_URL = 'https://api.themoviedb.org/3'
HEADERS = {
    "accept": "application/json",
    "Authorization": f"Bearer {TMDB_READ_ACCESS_TOKEN}"
}

# ========================================
# CORE FUNCTIONS
# ========================================

def get_comprehensive_movie_data(imdb_id):
    """
    Fetches Budget, Cast, Sequel Info, Collection, MPAA Rating, and Poster in just 2 API calls.

    Returns:
        dict with all movie data
    """
    # Default empty return structure
    empty_result = {
        'Budget': np.nan,
        'actors': np.nan,
        'cast_count': 0,
        'poster_url': np.nan,
        'is_sequel': 0,
        'collection_id': np.nan,
        'mpaa_rating': np.nan
    }

    if pd.isna(imdb_id) or not imdb_id:
        return empty_result

    imdb_id = str(imdb_id).strip()

    try:
        # --- CALL 1: Find TMDB ID from IMDb ID ---
        find_url = f"{TMDB_API_BASE_URL}/find/{imdb_id}"
        response = requests.get(find_url, headers=HEADERS, params={"external_source": "imdb_id"}, timeout=10)
        response.raise_for_status()
        results = response.json().get('movie_results', [])

        if not results:
            return empty_result

        tmdb_id = results[0]['id']

        # --- CALL 2: Get Details, Credits, AND Release Dates (OPTIMIZED!) ---
        # Using append_to_response to get everything in one call
        details_url = f"{TMDB_API_BASE_URL}/movie/{tmdb_id}"
        params = {"append_to_response": "credits,release_dates"}

        response = requests.get(details_url, headers=HEADERS, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        # ===== PARSE BUDGET =====
        budget = data.get('budget', 0)
        budget = budget if budget > 0 else np.nan

        # ===== PARSE POSTER =====
        poster_path = data.get('poster_path')
        poster_url = f"https://image.tmdb.org/t/p/original{poster_path}" if poster_path else np.nan

        # ===== PARSE CAST =====
        cast = data.get('credits', {}).get('cast', [])
        top_15_actors = [actor['name'] for actor in cast[:15]]

        actors_str = ', '.join(top_15_actors) if top_15_actors else np.nan
        cast_count = len(cast)

        # ===== PARSE COLLECTION INFO (Sequel Detection) =====
        belongs_to_collection = data.get('belongs_to_collection')

        is_sequel = 0
        collection_id = np.nan

        if belongs_to_collection:
            # If movie belongs to a collection, it's likely a sequel/franchise movie
            is_sequel = 1
            collection_id = belongs_to_collection.get('id')

        # ===== PARSE MPAA RATING =====
        mpaa_rating = np.nan
        release_dates_data = data.get('release_dates', {}).get('results', [])

        # Look for US release dates (contains MPAA ratings)
        for country_data in release_dates_data:
            if country_data.get('iso_3166_1') == 'US':
                release_info = country_data.get('release_dates', [])
                for release in release_info:
                    certification = release.get('certification', '').strip()
                    if certification:  # Get first non-empty certification
                        mpaa_rating = certification
                        break
                break

        return {
            'Budget': budget,
            'actors': actors_str,
            'cast_count': cast_count,
            'poster_url': poster_url,
            'is_sequel': is_sequel,
            'collection_id': collection_id,
            'mpaa_rating': mpaa_rating
        }

    except Exception as e:
        print(f"⚠️ Error on {imdb_id}: {e}")
        return empty_result
    finally:
        time.sleep(0.05)  # Rate limiting (safety buffer)

# ========================================
# MAIN EXECUTION
# ========================================

print("=" * 60)
print("🎬 COMPREHENSIVE MOVIE DATA ENRICHMENT")
print("=" * 60)

# 1. LOAD DATA (Resume Logic)
if os.path.exists(CHECKPOINT_FILE):
    print(f"🔄 Checkpoint found! Resuming from: {CHECKPOINT_FILE}")
    df = pd.read_csv(CHECKPOINT_FILE)
    df['tconst'] = df['tconst'].astype(str)
else:
    print(f"🆕 Starting fresh with your dataframe (df)")
    # df is already loaded in your environment - just ensure tconst is string
    df = df.copy()  # Make a copy to avoid modifying original
    df['tconst'] = df['tconst'].astype(str)

    # Initialize new columns
    new_cols = {
        'Budget': np.nan,
        'actors': np.nan,
        'cast_count': 0,
        'poster_url': np.nan,
        'is_sequel': 0,
        'collection_id': np.nan,
        'mpaa_rating': np.nan,
        'data_fetched': 0
    }

    for col, default_val in new_cols.items():
        df[col] = default_val

# 2. IDENTIFY REMAINING WORK
remaining_indices = df[df['data_fetched'] != 1].index
total_to_process = len(remaining_indices)

print(f"Movies already processed: {len(df) - total_to_process}")
print(f"Movies remaining: {total_to_process}")
print("-" * 60)

# 3. PROCESSING LOOP
start_time = time.time()
count = 0

for idx in remaining_indices:
    imdb_id = df.at[idx, 'tconst']

    # Fetch Data
    data = get_comprehensive_movie_data(imdb_id)

    # Update Row
    df.at[idx, 'Budget'] = data['Budget']
    df.at[idx, 'actors'] = data['actors']
    df.at[idx, 'cast_count'] = data['cast_count']
    df.at[idx, 'poster_url'] = data['poster_url']
    df.at[idx, 'is_sequel'] = data['is_sequel']
    df.at[idx, 'collection_id'] = data['collection_id']
    df.at[idx, 'mpaa_rating'] = data['mpaa_rating']

    # Mark as done
    df.at[idx, 'data_fetched'] = 1

    count += 1

    # Progress Update (Every 50 movies)
    if count % 50 == 0:
        elapsed = time.time() - start_time
        rate = count / elapsed
        remaining_est = (total_to_process - count) / rate if rate > 0 else 0
        print(f"⚡ Processed {count}/{total_to_process} | Rate: {rate:.1f} movies/sec | ETA: {remaining_est/60:.1f} min")

    # Checkpoint Save (Every 500 movies)
    if count % 500 == 0:
        df.to_csv(CHECKPOINT_FILE, index=False)
        print(f"💾 Checkpoint saved at {count} processed movies")

# 4. FINAL SAVES
print("-" * 60)
# Save final checkpoint
df.to_csv(CHECKPOINT_FILE, index=False)
print("💾 Final checkpoint saved")

# Save final output (drop the tracking column)
df_final = df.drop(columns=['data_fetched'])

# ========================================
# STATISTICS & SUMMARY
# ========================================

total_time = time.time() - start_time

print(f"\n⏱️ Processing Time: {total_time/60:.1f} minutes")
print(f"⚡ Average Rate: {count/total_time:.1f} movies/second")

print(f"\n💰 Budget Data:")
print(f"   Movies with budget: {df['Budget'].notna().sum()} ({df['Budget'].notna().sum()/len(df)*100:.1f}%)")
if df['Budget'].notna().any():
    print(f"   Average budget: ${df['Budget'].mean():,.0f}")
    print(f"   Median budget: ${df['Budget'].median():,.0f}")

print(f"\n🎭 Cast Data:")
print(f"   Movies with cast: {df['actors'].notna().sum()} ({df['actors'].notna().sum()/len(df)*100:.1f}%)")
print(f"   Average cast size: {df['cast_count'].mean():.1f} actors")

print(f"\n🎬 Poster Data:")
print(f"   Movies with posters: {df['poster_url'].notna().sum()} ({df['poster_url'].notna().sum()/len(df)*100:.1f}%)")

print(f"\n🎥 Sequel/Franchise Data:")
print(f"   Movies that are sequels/franchises: {df['is_sequel'].sum()} ({df['is_sequel'].sum()/len(df)*100:.1f}%)")
print(f"   Unique collections: {df['collection_id'].nunique()}")

print(f"\n🔞 MPAA Rating Data:")
print(f"   Movies with MPAA rating: {df['mpaa_rating'].notna().sum()} ({df['mpaa_rating'].notna().sum()/len(df)*100:.1f}%)")
if df['mpaa_rating'].notna().any():
    print(f"\n   Rating Distribution:")
    rating_counts = df['mpaa_rating'].value_counts()
    for rating, count in rating_counts.items():
        print(f"      {rating}: {count} ({count/len(df)*100:.1f}%)")

# Sample results
print("\n" + "=" * 60)
print("SAMPLE RESULTS (First 5 movies with data)")
print("=" * 60)
sample = df[df['actors'].notna()].head(5)
sample_cols = ['Release', 'Budget', 'cast_count', 'is_sequel', 'collection_id', 'mpaa_rating']
print(sample[sample_cols].to_string(index=False))

print("\n" + "=" * 60)
# Out:
# ============================================================
# 🎬 COMPREHENSIVE MOVIE DATA ENRICHMENT
# ============================================================
# 🆕 Starting fresh with your dataframe (df)
# Movies already processed: 0
# Movies remaining: 4840
# ------------------------------------------------------------
# /tmp/ipython-input-12146142.py:171: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Daniel Craig, Liev Schreiber, Jamie Bell, Alexa Davalos, Allan Corduner, Mark Feuerstein, Tomas Arana, Jodhi May, Kate Fahy, Iddo Goldberg, Iben Hjejle, Martin Hancock, Ravil Isyanov, Jacek Koman, George MacKay' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, 'actors'] = data['actors']
# /tmp/ipython-input-12146142.py:173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://image.tmdb.org/t/p/original/z6yNHcQOveRuAohuejdDFQDEBSs.jpg' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, 'poster_url'] = data['poster_url']
# /tmp/ipython-input-12146142.py:176: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'R' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[idx, 'mpaa_rating'] = data['mpaa_rating']
# ⚡ Processed 50/4840 | Rate: 5.4 movies/sec | ETA: 14.7 min
# ⚡ Processed 100/4840 | Rate: 5.3 movies/sec | ETA: 14.9 min
# ⚡ Processed 150/4840 | Rate: 5.3 movies/sec | ETA: 14.7 min
# ⚡ Processed 200/4840 | Rate: 5.3 movies/sec | ETA: 14.7 min
# ⚡ Processed 250/4840 | Rate: 5.3 movies/sec | ETA: 14.4 min
# ⚡ Processed 300/4840 | Rate: 5.3 movies/sec | ETA: 14.3 min
# ⚡ Processed 350/4840 | Rate: 5.3 movies/sec | ETA: 14.1 min
# ⚡ Processed 400/4840 | Rate: 5.3 movies/sec | ETA: 13.9 min
# ⚡ Processed 450/4840 | Rate: 5.3 movies/sec | ETA: 13.8 min
# ⚡ Processed 500/4840 | Rate: 5.3 movies/sec | ETA: 13.6 min
# 💾 Checkpoint saved at 500 processed movies
# ⚡ Processed 550/4840 | Rate: 5.3 movies/sec | ETA: 13.5 min
# ⚡ Processed 600/4840 | Rate: 5.3 movies/sec | ETA: 13.4 min
# ⚡ Processed 650/4840 | Rate: 5.3 movies/sec | ETA: 13.3 min
# ⚡ Processed 700/4840 | Rate: 5.2 movies/sec | ETA: 13.2 min
# ⚡ Processed 750/4840 | Rate: 5.2 movies/sec | ETA: 13.0 min
# ⚡ Processed 800/4840 | Rate: 5.2 movies/sec | ETA: 12.9 min
# ⚡ Processed 850/4840 | Rate: 5.2 movies/sec | ETA: 12.7 min
# ⚡ Processed 900/4840 | Rate: 5.2 movies/sec | ETA: 12.6 min
# ⚡ Processed 950/4840 | Rate: 5.2 movies/sec | ETA: 12.4 min
# ⚡ Processed 1000/4840 | Rate: 5.2 movies/sec | ETA: 12.3 min
# 💾 Checkpoint saved at 1000 processed movies
# ⚡ Processed 1050/4840 | Rate: 5.2 movies/sec | ETA: 12.1 min
# ⚡ Processed 1100/4840 | Rate: 5.2 movies/sec | ETA: 12.0 min
# ⚡ Processed 1150/4840 | Rate: 5.1 movies/sec | ETA: 12.0 min
# ⚡ Processed 1200/4840 | Rate: 5.1 movies/sec | ETA: 12.0 min
# ⚡ Processed 1250/4840 | Rate: 5.1 movies/sec | ETA: 11.8 min
# ⚡ Processed 1300/4840 | Rate: 5.1 movies/sec | ETA: 11.6 min
# ⚡ Processed 1350/4840 | Rate: 5.1 movies/sec | ETA: 11.5 min
# ⚡ Processed 1400/4840 | Rate: 5.0 movies/sec | ETA: 11.4 min
# ⚡ Processed 1450/4840 | Rate: 5.0 movies/sec | ETA: 11.4 min
# ⚡ Processed 1500/4840 | Rate: 4.9 movies/sec | ETA: 11.3 min
# 💾 Checkpoint saved at 1500 processed movies
# ⚡ Processed 1550/4840 | Rate: 4.9 movies/sec | ETA: 11.1 min
# ⚡ Processed 1600/4840 | Rate: 4.9 movies/sec | ETA: 10.9 min
# ⚡ Processed 1650/4840 | Rate: 4.9 movies/sec | ETA: 10.8 min
# ⚡ Processed 1700/4840 | Rate: 4.9 movies/sec | ETA: 10.7 min
# ⚡ Processed 1750/4840 | Rate: 4.9 movies/sec | ETA: 10.6 min
# ⚡ Processed 1800/4840 | Rate: 4.9 movies/sec | ETA: 10.4 min
# ⚡ Processed 1850/4840 | Rate: 4.9 movies/sec | ETA: 10.2 min
# ⚡ Processed 1900/4840 | Rate: 4.9 movies/sec | ETA: 10.1 min
# ⚡ Processed 1950/4840 | Rate: 4.9 movies/sec | ETA: 9.9 min
# ⚡ Processed 2000/4840 | Rate: 4.9 movies/sec | ETA: 9.7 min
# 💾 Checkpoint saved at 2000 processed movies
# ⚡ Processed 2050/4840 | Rate: 4.9 movies/sec | ETA: 9.5 min
# ⚡ Processed 2100/4840 | Rate: 4.9 movies/sec | ETA: 9.3 min
# ⚡ Processed 2150/4840 | Rate: 4.9 movies/sec | ETA: 9.1 min
# ⚡ Processed 2200/4840 | Rate: 4.9 movies/sec | ETA: 9.0 min
# ⚡ Processed 2250/4840 | Rate: 4.9 movies/sec | ETA: 8.8 min
# ⚡ Processed 2300/4840 | Rate: 4.9 movies/sec | ETA: 8.6 min
# ⚡ Processed 2350/4840 | Rate: 4.9 movies/sec | ETA: 8.4 min
# ⚡ Processed 2400/4840 | Rate: 4.9 movies/sec | ETA: 8.3 min
# ⚡ Processed 2450/4840 | Rate: 4.8 movies/sec | ETA: 8.3 min
# ⚡ Processed 2500/4840 | Rate: 4.8 movies/sec | ETA: 8.2 min
# 💾 Checkpoint saved at 2500 processed movies
# ⚡ Processed 2550/4840 | Rate: 4.8 movies/sec | ETA: 8.0 min
# ⚡ Processed 2600/4840 | Rate: 4.8 movies/sec | ETA: 7.8 min
# ⚡ Processed 2650/4840 | Rate: 4.8 movies/sec | ETA: 7.7 min
# ⚡ Processed 2700/4840 | Rate: 4.8 movies/sec | ETA: 7.5 min
# ⚡ Processed 2750/4840 | Rate: 4.8 movies/sec | ETA: 7.3 min
# ⚡ Processed 2800/4840 | Rate: 4.8 movies/sec | ETA: 7.1 min
# ⚡ Processed 2850/4840 | Rate: 4.8 movies/sec | ETA: 6.9 min
# ⚡ Processed 2900/4840 | Rate: 4.8 movies/sec | ETA: 6.7 min
# ⚡ Processed 2950/4840 | Rate: 4.8 movies/sec | ETA: 6.6 min
# ⚡ Processed 3000/4840 | Rate: 4.8 movies/sec | ETA: 6.4 min
# 💾 Checkpoint saved at 3000 processed movies
# ⚡ Processed 3050/4840 | Rate: 4.8 movies/sec | ETA: 6.2 min
# ⚡ Processed 3100/4840 | Rate: 4.8 movies/sec | ETA: 6.1 min
# ⚡ Processed 3150/4840 | Rate: 4.8 movies/sec | ETA: 5.9 min
# ⚡ Processed 3200/4840 | Rate: 4.7 movies/sec | ETA: 5.8 min
# ⚡ Processed 3250/4840 | Rate: 4.7 movies/sec | ETA: 5.6 min
# ⚡ Processed 3300/4840 | Rate: 4.7 movies/sec | ETA: 5.4 min
# ⚡ Processed 3350/4840 | Rate: 4.7 movies/sec | ETA: 5.2 min
# ⚡ Processed 3400/4840 | Rate: 4.7 movies/sec | ETA: 5.1 min
# ⚡ Processed 3450/4840 | Rate: 4.7 movies/sec | ETA: 4.9 min
# ⚡ Processed 3500/4840 | Rate: 4.7 movies/sec | ETA: 4.7 min
# 💾 Checkpoint saved at 3500 processed movies
# ⚡ Processed 3550/4840 | Rate: 4.7 movies/sec | ETA: 4.6 min
# ⚡ Processed 3600/4840 | Rate: 4.7 movies/sec | ETA: 4.4 min
# ⚡ Processed 3650/4840 | Rate: 4.7 movies/sec | ETA: 4.2 min
# ⚡ Processed 3700/4840 | Rate: 4.7 movies/sec | ETA: 4.1 min
# ⚡ Processed 3750/4840 | Rate: 4.7 movies/sec | ETA: 3.9 min
# ⚡ Processed 3800/4840 | Rate: 4.7 movies/sec | ETA: 3.7 min
# ⚡ Processed 3850/4840 | Rate: 4.7 movies/sec | ETA: 3.5 min
# ⚡ Processed 3900/4840 | Rate: 4.7 movies/sec | ETA: 3.3 min
# ⚡ Processed 3950/4840 | Rate: 4.7 movies/sec | ETA: 3.2 min
# ⚡ Processed 4000/4840 | Rate: 4.7 movies/sec | ETA: 3.0 min
# 💾 Checkpoint saved at 4000 processed movies
# ⚡ Processed 4050/4840 | Rate: 4.7 movies/sec | ETA: 2.8 min
# ⚡ Processed 4100/4840 | Rate: 4.7 movies/sec | ETA: 2.6 min
# ⚡ Processed 4150/4840 | Rate: 4.7 movies/sec | ETA: 2.5 min
# ⚡ Processed 4200/4840 | Rate: 4.7 movies/sec | ETA: 2.3 min
# ⚡ Processed 4250/4840 | Rate: 4.7 movies/sec | ETA: 2.1 min
# ⚡ Processed 4300/4840 | Rate: 4.7 movies/sec | ETA: 1.9 min
# ⚡ Processed 4350/4840 | Rate: 4.7 movies/sec | ETA: 1.7 min
# ⚡ Processed 4400/4840 | Rate: 4.7 movies/sec | ETA: 1.6 min
# ⚡ Processed 4450/4840 | Rate: 4.7 movies/sec | ETA: 1.4 min
# ⚡ Processed 4500/4840 | Rate: 4.7 movies/sec | ETA: 1.2 min
# 💾 Checkpoint saved at 4500 processed movies
# ⚡ Processed 4550/4840 | Rate: 4.7 movies/sec | ETA: 1.0 min
# ⚡ Processed 4600/4840 | Rate: 4.7 movies/sec | ETA: 0.8 min
# ⚡ Processed 4650/4840 | Rate: 4.7 movies/sec | ETA: 0.7 min
# ⚡ Processed 4700/4840 | Rate: 4.7 movies/sec | ETA: 0.5 min
# ⚡ Processed 4750/4840 | Rate: 4.7 movies/sec | ETA: 0.3 min
# ⚡ Processed 4800/4840 | Rate: 4.7 movies/sec | ETA: 0.1 min
# ------------------------------------------------------------
# 💾 Final checkpoint saved
# ✅ DONE! Final file saved as: dimension_table_enriched_final.csv
#
# ============================================================
# 📊 ENRICHMENT STATISTICS
# ============================================================
#
# ⏱️ Processing Time: 17.0 minutes
# ⚡ Average Rate: 4.7 movies/second
#
# 💰 Budget Data:
#    Movies with budget: 2811 (58.1%)
#    Average budget: $44,671,347
#    Median budget: $23,000,000
#
# 🎭 Cast Data:
#    Movies with cast: 4654 (96.2%)
#    Average cast size: 32.5 actors
#
# 🎬 Poster Data:
#    Movies with posters: 4730 (97.7%)
#
# 🎥 Sequel/Franchise Data:
#    Movies that are sequels/franchises: 848 (17.5%)
#    Unique collections: 501
#
# 🔞 MPAA Rating Data:
#    Movies with MPAA rating: 3751 (77.5%)
#
#    Rating Distribution:
#       R: 1621 (33.5%)
#       PG-13: 1277 (26.4%)
#       PG: 553 (11.4%)
#       NR: 245 (5.1%)
#       G: 50 (1.0%)
#       NC-17: 5 (0.1%)
#
# ============================================================
# SAMPLE RESULTS (First 5 movies with data)
# ============================================================
#            Release     Budget  cast_count  is_sequel  collection_id mpaa_rating
#           Defiance 32000000.0          73          0            NaN           R
# Revolutionary Road 35000000.0          60          0            NaN           R
#       Silent Light        NaN          14          0            NaN         NaN
#  Not Easily Broken        NaN          19          0            NaN          PG
#         Bride Wars 30000000.0          38          0            NaN          PG
#
# ============================================================

# %%
df_final.head()
# Out:
#       tconst             Release  Opening_Week_Revenue Release_Date Theaters  \
# 0  tt1034303            Defiance                195622   2009-01-01        2
# 1  tt0959337  Revolutionary Road                 76319   2009-01-01        3
# 2  tt0841925        Silent Light                 19633   2009-01-07        1
# 3  tt0795438   Not Easily Broken               6143981   2009-01-09      724
# 4  tt0901476          Bride Wars              25827125   2009-01-09    3,226
#
#    Release_Year            Distributor                genres runtimeMinutes  \
# 0          2009      Paramount Vantage  Action,Drama,History            137
# 1          2009      Paramount Vantage         Drama,Romance            119
# 2          2009       Palisades Tartan         Drama,Romance            136
# 3          2009            Screen Gems         Drama,Romance             99
# 4          2009  Twentieth Century Fox        Comedy,Romance             89
#
#    directors     Special_Day      Budget  \
# 0  nm0001880  New Year's Day  32000000.0
# 1  nm0005222  New Year's Day  35000000.0
# 2  nm1196161             NaN         NaN
# 3  nm0004886             NaN         NaN
# 4  nm0935095             NaN  30000000.0
#
#                                               actors  cast_count  \
# 0  Daniel Craig, Liev Schreiber, Jamie Bell, Alex...          73
# 1  Leonardo DiCaprio, Kate Winslet, Kathy Bates, ...          60
# 2  Cornelio Wall, Miriam Toews, Maria Pankratz, P...          14
# 3  Morris Chestnut, Taraji P. Henson, Maeve Quinl...          19
# 4  Kate Hudson, Anne Hathaway, Bryan Greenberg, C...          38
#
#                                           poster_url  is_sequel  \
# 0  https://image.tmdb.org/t/p/original/z6yNHcQOve...          0
# 1  https://image.tmdb.org/t/p/original/cvkD3yiVXL...          0
# 2  https://image.tmdb.org/t/p/original/kniOoQky3G...          0
# 3  https://image.tmdb.org/t/p/original/4HJ39DnQyf...          0
# 4  https://image.tmdb.org/t/p/original/eyXT8tmUoy...          0
#
#    collection_id mpaa_rating
# 0            NaN           R
# 1            NaN           R
# 2            NaN         NaN
# 3            NaN          PG
# 4            NaN          PG

# %%
df_final['Budget'].notna().sum()
# Out:
# np.int64(2811)

# %%
df_final.to_csv('dimension_table_final.csv', index=False)
